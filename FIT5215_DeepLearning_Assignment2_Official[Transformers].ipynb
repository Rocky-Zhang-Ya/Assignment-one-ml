# %% [markdown]
# # <font color="#0b486b">  FIT5215: Deep Learning (2025) - Assignment 2 (Section II)</font>
# ***
# *CE/Lecturer (Clayton):*  **Dr Trung Le** | trunglm@monash.edu <br/>
# *Lecturer (Clayton):* **A/Prof Zongyuan Ge** | zongyuan.ge@monash.edu <br/>
# *Lecturer (Malaysia):*  **Dr Arghya Pal** | arghya.pal@monash.edu <br/>
#  <br/>
# *Head Tutor 3181:*  **Ms Ruda Nie H** |  \[RudaNie.H@monash.edu \] <br/>
# *Head Tutor 5215:*  **Ms Leila Mahmoodi** |  \[leila.mahmoodi@monash.edu \]
#
# <br/> <br/>
# Faculty of Information Technology, Monash University, Australia
# ***

# %% [markdown]
# # <span style="color:#0b486b">  Student Information</span>
# ***
# Surname: **Zhang**  <br/>
# Firstname: **Xinyu**    <br/>
# Student ID: **35486244**    <br/>
# Email: **xzha0583@student.monash.edu**    <br/>
# Your tutorial time: **Tuesday, 8:00 – 10:00 PM**    <br/>
# ***

# %% [markdown]
# # <font color="0b486b">Assignment 2 – Deep Learning for Sequential Data</font>
# ### Due: <font color="red">11:55pm Sunday, 26 October 2025</font> (FIT5215)
#
# #### <font color="red">Important note:</font> This is an **individual** assignment. It contributes **20%** to your final mark. Read the assignment instructions carefully.

# %% [markdown]
# ## <font color="#0b486b">Assignment 2's Organization</font>
# This assignment 2 has two (2) sections:
# - Section 1: Fundamentals of RNNs (10 marks).
# - Section 2: Deep Learning for Sequential Data (90 marks). This section is further divided into 4 parts.
#
# The assignment 2 is organized in three (3) notebooks.
# - Notebook 1 ([link](https://colab.research.google.com/drive/1hTS6bWz6gU-lvi1qkIhrtQnJ3tzxRPFK?usp=sharing
# )) [Total: 30 marks] includes Section 1 as well as Part 1 and Part 2 of Section 2.
# - Notebook 2 ([link](https://colab.research.google.com/drive/1m0mh9Mk4-AKEhgAHRwQdl5mc0x7SF7Tv?usp=sharing)) [Total: 40 marks] includes Part 3 of Section 2.
# - Notebook 3 (this notebook) [Total: 30 marks] includes Part 4 of Section 2.

# %% [markdown]
# ## <font color="#0b486b">What to submit</font>
#
# This assignment is to be completed individually and submitted to Moodle unit site. **By the due date, you are required to submit one  <font color="red; font-weight:bold">single zip file, named xxx_assignment02_solution.zip</font> where `xxx` is your student ID, to the corresponding Assignment (Dropbox) in Moodle**. You can use Google Colab to do Assignment 2 but you need to save it to an `*.ipynb` file to submit to the unit Moodle.
#
# **More importantly, if you use Google Colab to do this assignment, you need to first make a copy of this notebook on your Google drive**.

# %% [markdown]
# ***For example, if your student ID is <font color="red; font-weight:bold">12356</font>, then gather all of your assignment solutions to a folder, create a zip file named <font color="red; font-weight:bold">123456_assignment02_solution.zip</font> and submit this file.***

# %% [markdown]
# Within this zip folder, you **must** submit the following files <u>for each part</u>:
# 1.	**`FIT5215_DeepLearning_Assignment2_Official[Main].ipynb`**:  this is your Python notebook solution source file.
# 1.	**`FIT5215_DeepLearning_Assignment2_Official[Main].html`**: this is the output of your Python notebook solution *exported* in HTML format.
# 1. **`FIT5215_DeepLearning_Assignment2_Official[RNNs].ipynb`**
# 1. **`FIT5215_DeepLearning_Assignment2_Official[RNNs].html`**
# 1. **`FIT5215_DeepLearning_Assignment2_Official[Transformers].ipynb`**
# 1. **`FIT5215_DeepLearning_Assignment2_Official[Transformers].html`**
# 1.	Any **extra files or folder** needed to complete your assignment (e.g., images used in your answers).

# %% [markdown]
# ## Section 2: Deep Learning for Sequential Data

# %% [markdown]
# ### <font color="#0b486b">Set random seeds</font>

# %% [markdown]
# We need to install the package datasets for creating BERT datasets.

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.35.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# We start with importing PyTorch and NumPy and setting random seeds for PyTorch and NumPy. You can use any seeds you prefer.

# %%
import os
import torch
import random
import requests
import pandas as pd
import numpy as np
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
from transformers import BertTokenizer
import os
from six.moves.urllib.request import urlretrieve
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
def seed_all(seed=1029):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
seed_all(seed=1234)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## <font color="#0b486b">Download and preprocess the data</font>
#
# <div style="text-align: right"><font color="red; font-weight:bold"><span></div>

# %% [markdown]
# The dataset we use for this assignment is a question classification dataset for which the training set consists of $5,500$ questions belonging to 6 coarse question categories including:
# - abbreviation (ABBR),
# - entity (ENTY),
# - description (DESC),
# - human (HUM),
# - location (LOC) and
# - numeric (NUM).
#
# In this assignment, we will utilize a subset of this dataset, containing $2,000$ questions for training and validation. We will use 80% of those 2000 questions for trainning and the rest for validation.

# %% [markdown]
# Preprocessing data is a crucial initial step in any machine learning or deep learning project. The *TextDataManager* class simplifies the process by providing functionalities to download and preprocess data specifically designed for the subsequent questions in this assignment. It is highly recommended to gain a comprehensive understanding of the class's functionality by **carefully reading** the content provided in the *TextDataManager* class before proceeding to answer the questions.

# %%
class DataManager:
    """
    This class manages and preprocesses a simple text dataset for a sentence classification task.

    Attributes:
        verbose (bool): Controls verbosity for printing information during data processing.
        max_sentence_len (int): The maximum length of a sentence in the dataset.
        str_questions (list): A list to store the string representations of the questions in the dataset.
        str_labels (list): A list to store the string representations of the labels in the dataset.
        numeral_labels (list): A list to store the numerical representations of the labels in the dataset.
        maxlen (int): Maximum length for padding sequences. Sequences longer than this length will be truncated,
            and sequences shorter than this length will be padded with zeros. Defaults to 50.
        numeral_data (list): A list to store the numerical representations of the questions in the dataset.
        random_state (int): Seed value for random number generation to ensure reproducibility.
            Set this value to a specific integer to reproduce the same random sequence every time. Defaults to 6789.
        random (np.random.RandomState): Random number generator object initialized with the given random_state.
            It is used for various random operations in the class.

    Methods:
        maybe_download(dir_name, file_name, url, verbose=True):
            Downloads a file from a given URL if it does not exist in the specified directory.
            The directory and file are created if they do not exist.

        read_data(dir_name, file_names):
            Reads data from files in a directory, preprocesses it, and computes the maximum sentence length.
            Each file is expected to contain rows in the format "<label>:<question>".
            The labels and questions are stored as string representations.

        manipulate_data():
            Performs data manipulation by tokenizing, numericalizing, and padding the text data.
            The questions are tokenized and converted into numerical sequences using a tokenizer.
            The sequences are padded or truncated to the maximum sequence length.

        train_valid_test_split(train_ratio=0.9):
            Splits the data into training, validation, and test sets based on a given ratio.
            The data is randomly shuffled, and the specified ratio is used to determine the size of the training set.
            The string questions, numerical data, and numerical labels are split accordingly.
            TensorFlow `Dataset` objects are created for the training and validation sets.


    """

    def __init__(self, verbose=True, random_state=6789):
        self.verbose = verbose
        self.max_sentence_len = 0
        self.str_questions = list()
        self.str_labels = list()
        self.numeral_labels = list()
        self.numeral_data = list()
        self.random_state = random_state
        self.random = np.random.RandomState(random_state)

    @staticmethod
    def maybe_download(dir_name, file_name, url, verbose=True):
        if not os.path.exists(dir_name):
            os.mkdir(dir_name)
        if not os.path.exists(os.path.join(dir_name, file_name)):
            urlretrieve(url + file_name, os.path.join(dir_name, file_name))
        if verbose:
            print("Downloaded successfully {}".format(file_name))

    def read_data(self, dir_name, file_names):
        self.str_questions = list()
        self.str_labels = list()
        for file_name in file_names:
            file_path= os.path.join(dir_name, file_name)
            with open(file_path, "r", encoding="latin-1") as f:
                for row in f:
                    row_str = row.split(":")
                    label, question = row_str[0], row_str[1]
                    question = question.lower()
                    self.str_labels.append(label)
                    self.str_questions.append(question[0:-1])
                    if self.max_sentence_len < len(self.str_questions[-1]):
                        self.max_sentence_len = len(self.str_questions[-1])

        # turns labels into numbers
        le = preprocessing.LabelEncoder()
        le.fit(self.str_labels)
        self.numeral_labels = np.array(le.transform(self.str_labels))
        self.str_classes = le.classes_
        self.num_classes = len(self.str_classes)
        if self.verbose:
            print("\nSample questions and corresponding labels... \n")
            print(self.str_questions[0:5])
            print(self.str_labels[0:5])

    def manipulate_data(self):
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
        vocab = self.tokenizer.get_vocab()
        self.word2idx = {w: i for i, w in enumerate(vocab)}
        self.idx2word = {i:w for w,i in self.word2idx.items()}
        self.vocab_size = len(self.word2idx)

        token_ids = []
        num_seqs = []
        for text in self.str_questions:  # iterate over the list of text
          text_seqs = self.tokenizer.tokenize(str(text))  # tokenize each text individually
          # Convert tokens to IDs
          token_ids = self.tokenizer.convert_tokens_to_ids(text_seqs)
          # Convert token IDs to a tensor of indices using your word2idx mapping
          seq_tensor = torch.LongTensor(token_ids)
          num_seqs.append(seq_tensor)  # append the tensor for each sequence

        # Pad the sequences and create a tensor
        if num_seqs:
          self.numeral_data = pad_sequence(num_seqs, batch_first=True)  # Pads to max length of the sequences
          self.num_sentences, self.max_seq_len = self.numeral_data.shape

    def train_valid_test_split(self, train_ratio=0.8, test_ratio = 0.1):
        train_size = int(self.num_sentences*train_ratio) +1
        test_size = int(self.num_sentences*test_ratio) +1
        valid_size = self.num_sentences - (train_size + test_size)
        data_indices = list(range(self.num_sentences))
        random.shuffle(data_indices)
        self.train_str_questions = [self.str_questions[i] for i in data_indices[:train_size]]
        self.train_numeral_labels = self.numeral_labels[data_indices[:train_size]]
        train_set_data = self.numeral_data[data_indices[:train_size]]
        train_set_labels = self.numeral_labels[data_indices[:train_size]]
        train_set_labels = torch.from_numpy(train_set_labels)
        train_set = torch.utils.data.TensorDataset(train_set_data, train_set_labels)
        self.test_str_questions = [self.str_questions[i] for i in data_indices[-test_size:]]
        self.test_numeral_labels = self.numeral_labels[data_indices[-test_size:]]
        test_set_data = self.numeral_data[data_indices[-test_size:]]
        test_set_labels = self.numeral_labels[data_indices[-test_size:]]
        test_set_labels = torch.from_numpy(test_set_labels)
        test_set = torch.utils.data.TensorDataset(test_set_data, test_set_labels)
        self.valid_str_questions = [self.str_questions[i] for i in data_indices[train_size:-test_size]]
        self.valid_numeral_labels = self.numeral_labels[data_indices[train_size:-test_size]]
        valid_set_data = self.numeral_data[data_indices[train_size:-test_size]]
        valid_set_labels = self.numeral_labels[data_indices[train_size:-test_size]]
        valid_set_labels = torch.from_numpy(valid_set_labels)
        valid_set = torch.utils.data.TensorDataset(valid_set_data, valid_set_labels)
        self.train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
        self.test_loader = DataLoader(test_set, batch_size=64, shuffle=False)
        self.valid_loader = DataLoader(valid_set, batch_size=64, shuffle=False)

# %%
# get the dataset
print('Loading data...')
DataManager.maybe_download("data", "train_2000.label", "http://cogcomp.org/Data/QA/QC/")

dm = DataManager()
dm.read_data("data/", ["train_2000.label"])
# Out:
# Loading data...
# Downloaded successfully train_2000.label
#
# Sample questions and corresponding labels...
#
# ['manner how did serfdom develop in and then leave russia ?', 'cremat what films featured the character popeye doyle ?', "manner how can i find a list of celebrities ' real names ?", 'animal what fowl grabs the spotlight after the chinese year of the monkey ?', 'exp what is the full form of .com ?']
# ['DESC', 'ENTY', 'DESC', 'ENTY', 'ABBR']

# %%
# !pip install ipywidgets
# make sure you have the latest libraries installed.
# !pip install huggingface_hub --upgrade
# Out:
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (7.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.5)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.9.0.post0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.14)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.5.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.17.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.27.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.23)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.11.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (24.11.1)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.9.0.20251008)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.2 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.19.2
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.35.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2025.10.5)

# %%
# Import and execute the login function
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
dm.manipulate_data()
dm.train_valid_test_split(train_ratio=0.8, test_ratio = 0.1)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
for x, y in dm.train_loader:
    print(x.shape, y.shape)
    break
# Out:
# torch.Size([64, 36]) torch.Size([64])

# %% [markdown]
# We now declare the `BaseTrainer` class, which will be used later to train the subsequent deep learning models for text data.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class BaseTrainer:
    def __init__(self, model, criterion, optimizer, train_loader, val_loader):
        self.model = model
        self.criterion = criterion  #the loss function
        self.optimizer = optimizer  #the optimizer
        self.train_loader = train_loader  #the train loader
        self.val_loader = val_loader  #the valid loader

    #the function to train the model in many epochs
    def fit(self, num_epochs):
        self.num_batches = len(self.train_loader)

        for epoch in range(num_epochs):
            print(f'Epoch {epoch + 1}/{num_epochs}')
            train_loss, train_accuracy = self.train_one_epoch()
            val_loss, val_accuracy = self.validate_one_epoch()
            print(
                f'{self.num_batches}/{self.num_batches} - train_loss: {train_loss:.4f} - train_accuracy: {train_accuracy*100:.4f}% \
                - val_loss: {val_loss:.4f} - val_accuracy: {val_accuracy*100:.4f}%')

    #train in one epoch, return the train_acc, train_loss
    def train_one_epoch(self):
        self.model.train()
        running_loss, correct, total = 0.0, 0, 0
        for i, data in enumerate(self.train_loader):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        train_accuracy = correct / total
        train_loss = running_loss / self.num_batches
        return train_loss, train_accuracy

    #evaluate on a loader and return the loss and accuracy
    def evaluate(self, loader):
        self.model.eval()
        loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for data in loader:
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = correct / total
        loss = loss / len(self.val_loader)
        return loss, accuracy

    #return the val_acc, val_loss, be called at the end of each epoch
    def validate_one_epoch(self):
      val_loss, val_accuracy = self.evaluate(self.val_loader)
      return val_loss, val_accuracy

# %% [markdown]
# ## <font color="#0b486b">Part 4: Transformer-based models for sequence modeling and neural embedding</font>
#
# <div style="text-align: right"><font color="red; font-weight:bold">[Total marks for this part: 30 marks]<span></div>

# %% [markdown]
# #### <font color="red">**Question 4.1**</font>
#
# **Implement the multi-head attention module of the Transformer for the text classification problem. The provided code is from our tutorial. In this part, we only use the output of the Transformer encoder for the classification task. For further information on the Transformer model, refer to [this paper](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf).**
#
# <div style="text-align: right"><font color="red; font-weight:bold">[Total marks for this part: 10 marks]<span></div>

# %% [markdown]
# Below is the code of `MultiHeadSelfAttention`, `PositionWiseFeedForward`, `PositionalEncoding`, and `EncoderLayer`.

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        # Ensure that the model dimension (d_model) is divisible by the number of heads
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"

        # Initialize dimensions
        self.d_model = d_model # Model's dimension
        self.num_heads = num_heads # Number of attention heads
        self.d_k = d_model // num_heads # Dimension of each head's key, query, and value

        # Linear layers for transforming inputs
        self.W_q = nn.Linear(d_model, d_model) # Query transformation
        self.W_k = nn.Linear(d_model, d_model) # Key transformation
        self.W_v = nn.Linear(d_model, d_model) # Value transformation
        self.W_o = nn.Linear(d_model, d_model) # Output transformation

    def scaled_dot_product_attention(self, Q, K, V):
        # Calculate attention scores
        attn_scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)

        # Apply mask if provided (useful for preventing attention to certain parts like padding)
        #if mask is not None:
            #attn_scores = attn_scores.masked_fill(mask == 0, -1e9)

        # Softmax is applied to obtain attention probabilities
        attn_probs = torch.softmax(attn_scores, dim=-1)

        # Multiply by values to obtain the final output
        output = torch.matmul(attn_probs, V)
        return output

    def split_heads(self, x):
        # Reshape the input to have num_heads for multi-head attention
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        # Combine the multiple heads back to original shape
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V):
        # Apply linear transformations and split heads
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))

        # Perform scaled dot-product attention
        attn_output = self.scaled_dot_product_attention(Q, K, V)

        # Combine heads and apply output transformation
        output = self.W_o(self.combine_heads(attn_output))
        return output

# %%
class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

# %%
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        attn_output = self.self_attn(x, x, x)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

# %% [markdown]
# Your task is to develop `TransformerClassifier` in which we input the embedding with the shape `[batch_size, seq_len, embed_dim]` to some `EncoderLayer` (i.e., num_layers specifies the number of EncoderLayer) and then compute the average of all token embeddings (i.e., `[batch_size, seq_len, embed_dim]`) across the `seq_len`. Finally, on the top of this average embedding, we build up a linear layer for making predictions.

# %%
class TransformerClassifier(nn.Module):
    def __init__(self, embed_dim, num_heads, ff_dim, num_layers, dropout_rate=0.2, data_manager = None):
        super(TransformerClassifier, self).__init__()
        self.vocab_size = data_manager.vocab_size
        self.num_classes = data_manager.num_classes
        self.embed_dim = embed_dim
        self.max_seq_len = data_manager.max_seq_len
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.num_layers = num_layers
        self.dropout_rate = dropout_rate

        # Initialize the layers in the build method
        self.embedding = None
        self.pos_encoder = None
        self.transformer_encoder = None
        self.fc = None
        self.dropout = None

    def build(self):
        #Insert your code here

        # Embedding Layer
        # Convert the input word index to a dense vector
        self.embedding = nn.Embedding(self.vocab_size, self.embed_dim)

        # Positional Encoding Layer
        # Provides the model with information about the word's position in the sequence
        self.pos_encoder = PositionalEncoding(self.embed_dim, self.max_seq_len)

        # Transformer Encoder Layer
        # Standard TransformerEncoderLayer module provided by PyTorch
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=self.embed_dim,
            nhead=self.num_heads,
            dim_feedforward=self.ff_dim,
            dropout=self.dropout_rate,
            batch_first=True # Set to True to match the (batch, seq, feature) input format.
        )

        # Transformer Encoder
        # Stacking Multiple Encoder Layers
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layer,
            num_layers=self.num_layers
        )

        # Fully Connected Layer
        # Maps the Transformer output to the final number of categories for classification
        self.fc = nn.Linear(self.embed_dim, self.num_classes)

        # Dropout layer
        # Used for regularization to prevent overfitting
        self.dropout = nn.Dropout(self.dropout_rate)



    def forward(self, x):
        #Insert your code here


        # Passing the embedding layer
        # Input x shape: (batch_size, seq_length)
        # Output emb shape: (batch_size, seq_length, embed_dim)
        emb = self.embedding(x)

        # Add positional encoding and apply dropout
        # Output pos_encoded shape: (batch_size, seq_length, embed_dim)
        pos_encoded = self.dropout(self.pos_encoder(emb))

        # Encoder via Transformer
        # Output encoder_output shape: (batch_size, seq_length, embed_dim)
        encoder_output = self.transformer_encoder(pos_encoded)

        # Pooling
        # Average pooling across the sequence dimension to obtain a sentence-level representation
        # Input encoder_output shape: (batch_size, seq_length, embed_dim)
        # Output pooled_output shape: (batch_size, embed_dim)
        pooled_output = encoder_output.mean(dim=1)

        # Pass the final fully connected layer
        # Output logits: shape: (batch_size, num_classes)
        logits = self.fc(pooled_output)

        return logits

# %%
transformer = TransformerClassifier(embed_dim=512, num_heads=8, ff_dim=2048, num_layers=12, dropout_rate=0.1, data_manager= dm)
transformer.build()
transformer = transformer.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(transformer.parameters(), lr=1e-4, betas=(0.9, 0.98), eps=1e-9)
trainer = BaseTrainer(model= transformer, criterion=criterion, optimizer=optimizer, train_loader=dm.train_loader, val_loader=dm.valid_loader)
trainer.fit(num_epochs=30)
# Out:
# Epoch 1/30
# 26/26 - train_loss: 1.8225 - train_accuracy: 21.6115%                 - val_loss: 0.7238 - val_accuracy: 27.2727%
# Epoch 2/30
# 26/26 - train_loss: 1.6739 - train_accuracy: 21.8613%                 - val_loss: 0.8950 - val_accuracy: 12.6263%
# Epoch 3/30
# 26/26 - train_loss: 1.7360 - train_accuracy: 20.3623%                 - val_loss: 0.8296 - val_accuracy: 26.2626%
# Epoch 4/30
# 26/26 - train_loss: 1.3737 - train_accuracy: 39.7252%                 - val_loss: 0.3421 - val_accuracy: 56.5657%
# Epoch 5/30
# 26/26 - train_loss: 0.6333 - train_accuracy: 72.4547%                 - val_loss: 0.7553 - val_accuracy: 58.0808%
# Epoch 6/30
# 26/26 - train_loss: 0.5715 - train_accuracy: 75.5153%                 - val_loss: 0.3722 - val_accuracy: 68.6869%
# Epoch 7/30
# 26/26 - train_loss: 0.3616 - train_accuracy: 85.1968%                 - val_loss: 0.0497 - val_accuracy: 91.9192%
# Epoch 8/30
# 26/26 - train_loss: 0.2287 - train_accuracy: 92.0675%                 - val_loss: 0.0301 - val_accuracy: 92.4242%
# Epoch 9/30
# 26/26 - train_loss: 0.1794 - train_accuracy: 94.3161%                 - val_loss: 0.0176 - val_accuracy: 95.9596%
# Epoch 10/30
# 26/26 - train_loss: 0.1565 - train_accuracy: 94.7533%                 - val_loss: 0.0287 - val_accuracy: 93.9394%
# Epoch 11/30
# 26/26 - train_loss: 0.1609 - train_accuracy: 94.6908%                 - val_loss: 0.0105 - val_accuracy: 93.9394%
# Epoch 12/30
# 26/26 - train_loss: 0.1476 - train_accuracy: 95.7527%                 - val_loss: 0.0090 - val_accuracy: 96.4646%
# Epoch 13/30
# 26/26 - train_loss: 0.0963 - train_accuracy: 96.6896%                 - val_loss: 0.0016 - val_accuracy: 96.4646%
# Epoch 14/30
# 26/26 - train_loss: 0.0550 - train_accuracy: 97.8139%                 - val_loss: 0.0004 - val_accuracy: 96.9697%
# Epoch 15/30
# 26/26 - train_loss: 0.0376 - train_accuracy: 98.6883%                 - val_loss: 0.0049 - val_accuracy: 92.9293%
# Epoch 16/30
# 26/26 - train_loss: 0.0823 - train_accuracy: 97.0643%                 - val_loss: 0.0070 - val_accuracy: 94.4444%
# Epoch 17/30
# 26/26 - train_loss: 0.0478 - train_accuracy: 98.5634%                 - val_loss: 0.0003 - val_accuracy: 95.4545%
# Epoch 18/30
# 26/26 - train_loss: 0.0296 - train_accuracy: 99.0006%                 - val_loss: 0.0012 - val_accuracy: 93.9394%
# Epoch 19/30
# 26/26 - train_loss: 0.0423 - train_accuracy: 98.4385%                 - val_loss: 0.0007 - val_accuracy: 95.9596%
# Epoch 20/30
# 26/26 - train_loss: 0.0611 - train_accuracy: 98.1262%                 - val_loss: 0.0005 - val_accuracy: 94.9495%
# Epoch 21/30
# 26/26 - train_loss: 0.0306 - train_accuracy: 98.8132%                 - val_loss: 0.0008 - val_accuracy: 95.9596%
# Epoch 22/30
# 26/26 - train_loss: 0.0169 - train_accuracy: 99.3129%                 - val_loss: 0.0004 - val_accuracy: 96.4646%
# Epoch 23/30
# 26/26 - train_loss: 0.0322 - train_accuracy: 99.0006%                 - val_loss: 0.0005 - val_accuracy: 94.9495%
# Epoch 24/30
# 26/26 - train_loss: 0.0183 - train_accuracy: 99.6877%                 - val_loss: 0.0002 - val_accuracy: 95.4545%
# Epoch 25/30
# 26/26 - train_loss: 0.0354 - train_accuracy: 99.0006%                 - val_loss: 0.0001 - val_accuracy: 94.9495%
# Epoch 26/30
# 26/26 - train_loss: 0.0035 - train_accuracy: 99.9375%                 - val_loss: 0.0002 - val_accuracy: 97.9798%
# Epoch 27/30
# 26/26 - train_loss: 0.2373 - train_accuracy: 98.4385%                 - val_loss: 0.0056 - val_accuracy: 95.9596%
# Epoch 28/30
# 26/26 - train_loss: 0.1314 - train_accuracy: 95.0656%                 - val_loss: 0.0039 - val_accuracy: 97.4747%
# Epoch 29/30
# 26/26 - train_loss: 0.0358 - train_accuracy: 99.2505%                 - val_loss: 0.0023 - val_accuracy: 97.4747%
# Epoch 30/30
# 26/26 - train_loss: 0.0335 - train_accuracy: 99.3129%                 - val_loss: 0.0013 - val_accuracy: 96.9697%

# %% [markdown]
# #### <font color="red">**Question 4.2**</font>
# **Prefix prompt-tuning with Transformers: You need to implement the prefix prompt-tuning with Transformers. Basically, we base on a pre-trained Transformer, add prefix prompts, and do fine-tuning for a target dataset.**
#
# <div style="text-align: right"><font color="red; font-weight:bold">[Total marks for this part: 10 marks]<span></div>

# %% [markdown]
# To implement prefix prompt-tuning with pretrained Transformers, we first need to create the Bert dataset.

# %%
from transformers import AutoModel, AutoTokenizer
from torch.optim import AdamW
from datasets import Dataset

model_name = "bert-base-uncased"  # BERT or any similar model

# Tokenize input and prepare model inputs
tokenizer = AutoTokenizer.from_pretrained(model_name)

dataset = Dataset.from_dict({"text": dm.str_questions, "label": dm.numeral_labels})

# Tokenize the dataset
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length= 36)

dataset = dataset.map(tokenize_function, batched=True)
dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
print(dataset)
# Out:
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 2000
# })

# %% [markdown]
# The following function splits the BERT dataset `dataset` into three BERT datasets for training, valid, and testing.

# %%
def train_valid_test_split(dataset, train_ratio=0.8, test_ratio = 0.1):
    num_sentences = len(dataset)
    train_size = int(num_sentences*train_ratio) +1
    test_size = int(num_sentences*test_ratio) +1
    valid_size = num_sentences - (train_size + test_size)
    train_set = dataset[:train_size]
    train_set = Dataset.from_dict(train_set)
    train_set.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    test_set = dataset[-test_size:]
    test_set = Dataset.from_dict(test_set)
    test_set.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    valid_set = dataset[train_size:-test_size]
    valid_set = Dataset.from_dict(valid_set)
    valid_set.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
    test_loader = DataLoader(test_set, batch_size=64, shuffle=False)
    valid_loader = DataLoader(valid_set, batch_size=64, shuffle=False)
    return train_loader, test_loader, valid_loader

# %%
train_loader, test_loader, valid_loader = train_valid_test_split(dataset)

# %% [markdown]
# You need to implement the class `PrefixTuningForClassification` for the prefix prompt fine-tuning. We first load a pre-trained BERT model specified by `model_name`. The parameter `prefix_length` specifies the length of the prefix prompts we add to the pre-trained BERT model. Specifically, given the input batch `[batch_size, seq_len]`, we input to the embedding layer of the pre-trained BERT model to obtain `[batch_size, seq_len, embed_size]`. We create the prefix prompts $P$ of the size `[prefix_length, embed_size]` and concatenate to the embeddings from the pre-trained BERT to obtain `[batch_size, seq_len + prefix_length, embed_size]`. This concatenation tensor will then be fed to the encoder layers of the pre-trained BERT layer to obtain the last `[batch_size, seq_len + prefix_length, embed_size]`.

# %% [markdown]
# We then take mean across the seq_len to obtain `[batch_size, embed_size]` on which we can build up a linear layer for making predictions. Please note that **the parameters to tune include the prefix prompts $P$** and **the output linear layer**, and you should freeze the parameters of the BERT pre-trained model. Moreover, your code should cover the edge case when `prefix_length=None`. In this case, we do not insert any prefix prompts and we only do fine-tuning for the output linear layer on top.

# %%
class PrefixTuningForClassification(nn.Module):
    def __init__(self, model_name, prefix_length=None, data_manager = None):
        super(PrefixTuningForClassification, self).__init__()

        # Load the pretrained transformer model (BERT-like model)
        self.model = AutoModel.from_pretrained(model_name).to(device)
        self.hidden_size =  self.model.config.hidden_size
        self.prefix_length = prefix_length
        self.num_classes = data_manager.num_classes
        # Insert your code here

        # Freeze all parameters of the pre-trained model
        for param in self.model.parameters():
            param.requires_grad = False

        # Insert your code here
        # Initialize Prefix Embeddings
        # If prefix_length is not None, create a trainable prefix vector
        if self.prefix_length is not None:
            self.prefix_embeddings = nn.Parameter(
                torch.randn(self.prefix_length, self.hidden_size)
            )

        #  Initialize the classifier
        # Create a linear layer as the classification head. This layer is trainable.
        self.classifier = nn.Linear(self.hidden_size, self.num_classes)

    def forward(self, input_ids, attention_mask):
       

        # Get the original word embeddings
        # Convert input_ids to vectors using the model's embedding layer
        # Shape of inputs_embeds: (batch_size, seq_len, hidden_size)
        inputs_embeds = self.model.embeddings.word_embeddings(input_ids)

        # If prefix is defined, concatenate the prefix
        if self.prefix_length is not None:
            batch_size = inputs_embeds.size(0)

            # Expand shared prefix_embeddings to the current batch size
            # Shape of expanded_prefix_embeds: (batch_size, prefix_len, hidden_size)
            expanded_prefix_embeds = self.prefix_embeddings.unsqueeze(0).expand(batch_size, -1, -1)

            # Append prefix to the beginning of the sequence dimension (dim=1)
            # New shape of inputs_embeds: (batch_size, seq_len + prefix_len, hidden_size)
            inputs_embeds = torch.cat([expanded_prefix_embeds, inputs_embeds], dim=1)

            # Create and concatenate the corresponding attention_mask
            prefix_mask = torch.ones(batch_size, self.prefix_length).to(self.model.device)
            attention_mask = torch.cat([prefix_mask, attention_mask], dim=1)

        # Pass the concatenated embedding vectors to the pre-trained model
        # Note: Pass inputs_embeds here, not input_ids
        outputs = self.model(inputs_embeds=inputs_embeds, attention_mask=attention_mask)

        # Get the output of the last layer of the model
        # Shape of last_hidden_state: (batch_size, seq_len + prefix_len, hidden_size)
        last_hidden_state = outputs.last_hidden_state

        # Pooling
        # Average the outputs along the sequence dimension to obtain a representation of the entire sequence.
        # Shape of pooled_output: (batch_size, hidden_size)
        pooled_output = last_hidden_state.mean(dim=1)

        # Obtain the final logits using the classifier
        # Logits shape: (batch_size, num_classes)
        logits = self.classifier(pooled_output)

        return logits

# %% [markdown]
# You can use the following `FineTunedBaseTrainer` to train the prompt fine-tuning models.

# %%
class FineTunedBaseTrainer:
    def __init__(self, model, criterion, optimizer, train_loader, val_loader):
        self.model = model
        self.criterion = criterion  #the loss function
        self.optimizer = optimizer  #the optimizer
        self.train_loader = train_loader  #the train loader
        self.val_loader = val_loader  #the valid loader

    #the function to train the model in many epochs
    def fit(self, num_epochs):
        self.num_batches = len(self.train_loader)

        for epoch in range(num_epochs):
            print(f'Epoch {epoch + 1}/{num_epochs}')
            train_loss, train_accuracy = self.train_one_epoch()
            val_loss, val_accuracy = self.validate_one_epoch()
            print(
                f'{self.num_batches}/{self.num_batches} - train_loss: {train_loss:.4f} - train_accuracy: {train_accuracy*100:.4f}% \
                - val_loss: {val_loss:.4f} - val_accuracy: {val_accuracy*100:.4f}%')

    #train in one epoch, return the train_acc, train_loss
    def train_one_epoch(self):
        self.model.train()
        running_loss, correct, total = 0.0, 0, 0
        for batch in self.train_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)
            self.optimizer.zero_grad()
            outputs = self.model(input_ids= input_ids, attention_mask= attention_mask)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        train_accuracy = correct / total
        train_loss = running_loss / self.num_batches
        return train_loss, train_accuracy

    #evaluate on a loader and return the loss and accuracy
    def evaluate(self, loader):
        self.model.eval()
        loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for batch in loader:
                input_ids = batch["input_ids"].to(device)
                labels = batch["label"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                outputs = self.model(input_ids= input_ids, attention_mask= attention_mask)
                loss = self.criterion(outputs, labels)
                loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = correct / total
        loss = loss / len(self.val_loader)
        return loss, accuracy

    #return the val_acc, val_loss, be called at the end of each epoch
    def validate_one_epoch(self):
      val_loss, val_accuracy = self.evaluate(self.val_loader)
      return val_loss, val_accuracy

# %% [markdown]
# We declare and train the prefix-prompt tuning model. In addition, you need to be patient with this model because it might converge slowly with many epochs.

# %%
prefix_tuning_model = PrefixTuningForClassification(model_name = "bert-base-uncased", prefix_length = 5, data_manager = dm).to(device)

# %%
if prefix_tuning_model.prefix_length is not None:
  optimizer = torch.optim.Adam(list(prefix_tuning_model.classifier.parameters()) + [prefix_tuning_model.prefix_embeddings], lr=5e-5)
else:
  optimizer = torch.optim.Adam(prefix_tuning_model.classifier.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()
trainer = FineTunedBaseTrainer(model= prefix_tuning_model, criterion=criterion, optimizer=optimizer, train_loader=train_loader, val_loader=valid_loader)
trainer.fit(num_epochs=100)
# Out:
# Epoch 1/100
# 26/26 - train_loss: 1.7917 - train_accuracy: 22.1112%                 - val_loss: 0.9028 - val_accuracy: 23.2323%
# Epoch 2/100
# 26/26 - train_loss: 1.7362 - train_accuracy: 25.6715%                 - val_loss: 0.8749 - val_accuracy: 26.2626%
# Epoch 3/100
# 26/26 - train_loss: 1.7117 - train_accuracy: 31.4179%                 - val_loss: 0.8505 - val_accuracy: 29.7980%
# Epoch 4/100
# 26/26 - train_loss: 1.6761 - train_accuracy: 33.2292%                 - val_loss: 0.8323 - val_accuracy: 33.3333%
# Epoch 5/100
# 26/26 - train_loss: 1.6442 - train_accuracy: 36.2274%                 - val_loss: 0.8159 - val_accuracy: 35.3535%
# Epoch 6/100
# 26/26 - train_loss: 1.6377 - train_accuracy: 39.3504%                 - val_loss: 0.7988 - val_accuracy: 40.4040%
# Epoch 7/100
# 26/26 - train_loss: 1.6006 - train_accuracy: 41.5990%                 - val_loss: 0.7882 - val_accuracy: 44.4444%
# Epoch 8/100
# 26/26 - train_loss: 1.5898 - train_accuracy: 43.2854%                 - val_loss: 0.7812 - val_accuracy: 47.4747%
# Epoch 9/100
# 26/26 - train_loss: 1.5670 - train_accuracy: 47.2205%                 - val_loss: 0.7711 - val_accuracy: 51.5152%
# Epoch 10/100
# 26/26 - train_loss: 1.5569 - train_accuracy: 48.2199%                 - val_loss: 0.7575 - val_accuracy: 53.0303%
# Epoch 11/100
# 26/26 - train_loss: 1.5558 - train_accuracy: 49.4691%                 - val_loss: 0.7489 - val_accuracy: 55.5556%
# Epoch 12/100
# 26/26 - train_loss: 1.5221 - train_accuracy: 51.6552%                 - val_loss: 0.7395 - val_accuracy: 57.5758%
# Epoch 13/100
# 26/26 - train_loss: 1.4996 - train_accuracy: 53.5915%                 - val_loss: 0.7314 - val_accuracy: 58.5859%
# Epoch 14/100
# 26/26 - train_loss: 1.4909 - train_accuracy: 55.1530%                 - val_loss: 0.7263 - val_accuracy: 59.5960%
# Epoch 15/100
# 26/26 - train_loss: 1.4762 - train_accuracy: 54.8407%                 - val_loss: 0.7190 - val_accuracy: 59.5960%
# Epoch 16/100
# 26/26 - train_loss: 1.4725 - train_accuracy: 55.5903%                 - val_loss: 0.7125 - val_accuracy: 61.1111%
# Epoch 17/100
# 26/26 - train_loss: 1.4599 - train_accuracy: 56.4647%                 - val_loss: 0.7064 - val_accuracy: 60.6061%
# Epoch 18/100
# 26/26 - train_loss: 1.4550 - train_accuracy: 58.6508%                 - val_loss: 0.6994 - val_accuracy: 62.1212%
# Epoch 19/100
# 26/26 - train_loss: 1.4346 - train_accuracy: 60.2748%                 - val_loss: 0.6889 - val_accuracy: 64.6465%
# Epoch 20/100
# 26/26 - train_loss: 1.4087 - train_accuracy: 62.7108%                 - val_loss: 0.6796 - val_accuracy: 66.6667%
# Epoch 21/100
# 26/26 - train_loss: 1.4175 - train_accuracy: 64.9594%                 - val_loss: 0.6654 - val_accuracy: 66.6667%
# Epoch 22/100
# 26/26 - train_loss: 1.3975 - train_accuracy: 63.9600%                 - val_loss: 0.6575 - val_accuracy: 68.6869%
# Epoch 23/100
# 26/26 - train_loss: 1.3861 - train_accuracy: 65.6465%                 - val_loss: 0.6502 - val_accuracy: 70.7071%
# Epoch 24/100
# 26/26 - train_loss: 1.3880 - train_accuracy: 63.9600%                 - val_loss: 0.6423 - val_accuracy: 71.7172%
# Epoch 25/100
# 26/26 - train_loss: 1.3620 - train_accuracy: 67.2705%                 - val_loss: 0.6348 - val_accuracy: 72.7273%
# Epoch 26/100
# 26/26 - train_loss: 1.3426 - train_accuracy: 66.8957%                 - val_loss: 0.6256 - val_accuracy: 73.2323%
# Epoch 27/100
# 26/26 - train_loss: 1.3413 - train_accuracy: 67.6452%                 - val_loss: 0.6123 - val_accuracy: 73.2323%
# Epoch 28/100
# 26/26 - train_loss: 1.3366 - train_accuracy: 67.8326%                 - val_loss: 0.6025 - val_accuracy: 73.2323%
# Epoch 29/100
# 26/26 - train_loss: 1.3262 - train_accuracy: 68.2074%                 - val_loss: 0.5981 - val_accuracy: 75.2525%
# Epoch 30/100
# 26/26 - train_loss: 1.3096 - train_accuracy: 67.7701%                 - val_loss: 0.5933 - val_accuracy: 75.7576%
# Epoch 31/100
# 26/26 - train_loss: 1.2969 - train_accuracy: 68.6446%                 - val_loss: 0.5869 - val_accuracy: 75.2525%
# Epoch 32/100
# 26/26 - train_loss: 1.3000 - train_accuracy: 69.2692%                 - val_loss: 0.5790 - val_accuracy: 76.2626%
# Epoch 33/100
# 26/26 - train_loss: 1.2867 - train_accuracy: 72.5796%                 - val_loss: 0.5760 - val_accuracy: 78.7879%
# Epoch 34/100
# 26/26 - train_loss: 1.2997 - train_accuracy: 72.2673%                 - val_loss: 0.5713 - val_accuracy: 78.2828%
# Epoch 35/100
# 26/26 - train_loss: 1.2730 - train_accuracy: 72.9544%                 - val_loss: 0.5632 - val_accuracy: 79.7980%
# Epoch 36/100
# 26/26 - train_loss: 1.2546 - train_accuracy: 72.5172%                 - val_loss: 0.5507 - val_accuracy: 79.2929%
# Epoch 37/100
# 26/26 - train_loss: 1.2431 - train_accuracy: 74.1412%                 - val_loss: 0.5457 - val_accuracy: 79.2929%
# Epoch 38/100
# 26/26 - train_loss: 1.2305 - train_accuracy: 75.5778%                 - val_loss: 0.5403 - val_accuracy: 80.8081%
# Epoch 39/100
# 26/26 - train_loss: 1.2205 - train_accuracy: 75.8276%                 - val_loss: 0.5341 - val_accuracy: 80.3030%
# Epoch 40/100
# 26/26 - train_loss: 1.2148 - train_accuracy: 75.8276%                 - val_loss: 0.5276 - val_accuracy: 81.3131%
# Epoch 41/100
# 26/26 - train_loss: 1.2111 - train_accuracy: 76.4522%                 - val_loss: 0.5245 - val_accuracy: 81.3131%
# Epoch 42/100
# 26/26 - train_loss: 1.2143 - train_accuracy: 75.3279%                 - val_loss: 0.5179 - val_accuracy: 82.8283%
# Epoch 43/100
# 26/26 - train_loss: 1.1675 - train_accuracy: 77.5765%                 - val_loss: 0.5095 - val_accuracy: 82.3232%
# Epoch 44/100
# 26/26 - train_loss: 1.1722 - train_accuracy: 78.2011%                 - val_loss: 0.5061 - val_accuracy: 81.8182%
# Epoch 45/100
# 26/26 - train_loss: 1.1545 - train_accuracy: 77.8264%                 - val_loss: 0.5013 - val_accuracy: 81.8182%
# Epoch 46/100
# 26/26 - train_loss: 1.1521 - train_accuracy: 77.8264%                 - val_loss: 0.4927 - val_accuracy: 81.3131%
# Epoch 47/100
# 26/26 - train_loss: 1.1570 - train_accuracy: 77.7639%                 - val_loss: 0.4848 - val_accuracy: 80.8081%
# Epoch 48/100
# 26/26 - train_loss: 1.1297 - train_accuracy: 76.3898%                 - val_loss: 0.4833 - val_accuracy: 81.3131%
# Epoch 49/100
# 26/26 - train_loss: 1.1231 - train_accuracy: 78.2636%                 - val_loss: 0.4776 - val_accuracy: 82.8283%
# Epoch 50/100
# 26/26 - train_loss: 1.1250 - train_accuracy: 79.3254%                 - val_loss: 0.4727 - val_accuracy: 83.8384%
# Epoch 51/100
# 26/26 - train_loss: 1.1911 - train_accuracy: 79.2005%                 - val_loss: 0.4649 - val_accuracy: 82.3232%
# Epoch 52/100
# 26/26 - train_loss: 1.1009 - train_accuracy: 78.7633%                 - val_loss: 0.4609 - val_accuracy: 82.8283%
# Epoch 53/100
# 26/26 - train_loss: 1.1786 - train_accuracy: 79.8251%                 - val_loss: 0.4560 - val_accuracy: 83.8384%
# Epoch 54/100
# 26/26 - train_loss: 1.0852 - train_accuracy: 79.9500%                 - val_loss: 0.4516 - val_accuracy: 83.8384%
# Epoch 55/100
# 26/26 - train_loss: 1.0526 - train_accuracy: 81.2617%                 - val_loss: 0.4475 - val_accuracy: 83.3333%
# Epoch 56/100
# 26/26 - train_loss: 1.0641 - train_accuracy: 80.3248%                 - val_loss: 0.4405 - val_accuracy: 83.3333%
# Epoch 57/100
# 26/26 - train_loss: 1.0464 - train_accuracy: 81.2617%                 - val_loss: 0.4341 - val_accuracy: 82.8283%
# Epoch 58/100
# 26/26 - train_loss: 1.0502 - train_accuracy: 81.6365%                 - val_loss: 0.4296 - val_accuracy: 83.3333%
# Epoch 59/100
# 26/26 - train_loss: 1.0548 - train_accuracy: 80.6371%                 - val_loss: 0.4243 - val_accuracy: 83.3333%
# Epoch 60/100
# 26/26 - train_loss: 1.0141 - train_accuracy: 81.1993%                 - val_loss: 0.4221 - val_accuracy: 83.3333%
# Epoch 61/100
# 26/26 - train_loss: 1.0405 - train_accuracy: 80.6371%                 - val_loss: 0.4170 - val_accuracy: 83.8384%
# Epoch 62/100
# 26/26 - train_loss: 1.0309 - train_accuracy: 80.8869%                 - val_loss: 0.4146 - val_accuracy: 84.3434%
# Epoch 63/100
# 26/26 - train_loss: 1.0171 - train_accuracy: 80.2623%                 - val_loss: 0.4118 - val_accuracy: 84.3434%
# Epoch 64/100
# 26/26 - train_loss: 1.0045 - train_accuracy: 81.1993%                 - val_loss: 0.4069 - val_accuracy: 84.8485%
# Epoch 65/100
# 26/26 - train_loss: 0.9791 - train_accuracy: 81.1993%                 - val_loss: 0.4060 - val_accuracy: 84.3434%
# Epoch 66/100
# 26/26 - train_loss: 1.0041 - train_accuracy: 80.8245%                 - val_loss: 0.4036 - val_accuracy: 84.3434%
# Epoch 67/100
# 26/26 - train_loss: 0.9726 - train_accuracy: 81.4491%                 - val_loss: 0.4003 - val_accuracy: 84.3434%
# Epoch 68/100
# 26/26 - train_loss: 0.9676 - train_accuracy: 81.8863%                 - val_loss: 0.3930 - val_accuracy: 84.3434%
# Epoch 69/100
# 26/26 - train_loss: 0.9633 - train_accuracy: 82.9482%                 - val_loss: 0.3898 - val_accuracy: 85.3535%
# Epoch 70/100
# 26/26 - train_loss: 0.9428 - train_accuracy: 82.5109%                 - val_loss: 0.3849 - val_accuracy: 84.3434%
# Epoch 71/100
# 26/26 - train_loss: 0.9500 - train_accuracy: 82.6983%                 - val_loss: 0.3791 - val_accuracy: 84.3434%
# Epoch 72/100
# 26/26 - train_loss: 0.9416 - train_accuracy: 82.4485%                 - val_loss: 0.3771 - val_accuracy: 85.8586%
# Epoch 73/100
# 26/26 - train_loss: 0.9248 - train_accuracy: 82.4485%                 - val_loss: 0.3713 - val_accuracy: 85.3535%
# Epoch 74/100
# 26/26 - train_loss: 0.9575 - train_accuracy: 83.2605%                 - val_loss: 0.3678 - val_accuracy: 84.8485%
# Epoch 75/100
# 26/26 - train_loss: 0.9135 - train_accuracy: 83.2605%                 - val_loss: 0.3645 - val_accuracy: 84.8485%
# Epoch 76/100
# 26/26 - train_loss: 0.9129 - train_accuracy: 83.8226%                 - val_loss: 0.3620 - val_accuracy: 84.8485%
# Epoch 77/100
# 26/26 - train_loss: 0.9005 - train_accuracy: 83.6352%                 - val_loss: 0.3592 - val_accuracy: 85.8586%
# Epoch 78/100
# 26/26 - train_loss: 0.9208 - train_accuracy: 83.8851%                 - val_loss: 0.3549 - val_accuracy: 85.3535%
# Epoch 79/100
# 26/26 - train_loss: 0.8788 - train_accuracy: 83.6977%                 - val_loss: 0.3511 - val_accuracy: 86.3636%
# Epoch 80/100
# 26/26 - train_loss: 0.8787 - train_accuracy: 84.2598%                 - val_loss: 0.3469 - val_accuracy: 86.3636%
# Epoch 81/100
# 26/26 - train_loss: 0.9029 - train_accuracy: 84.3223%                 - val_loss: 0.3446 - val_accuracy: 86.3636%
# Epoch 82/100
# 26/26 - train_loss: 0.8559 - train_accuracy: 85.2592%                 - val_loss: 0.3460 - val_accuracy: 84.8485%
# Epoch 83/100
# 26/26 - train_loss: 0.8541 - train_accuracy: 84.3848%                 - val_loss: 0.3445 - val_accuracy: 84.8485%
# Epoch 84/100
# 26/26 - train_loss: 0.8559 - train_accuracy: 84.1974%                 - val_loss: 0.3399 - val_accuracy: 84.8485%
# Epoch 85/100
# 26/26 - train_loss: 0.8843 - train_accuracy: 84.1974%                 - val_loss: 0.3359 - val_accuracy: 85.3535%
# Epoch 86/100
# 26/26 - train_loss: 0.8643 - train_accuracy: 83.5728%                 - val_loss: 0.3324 - val_accuracy: 85.3535%
# Epoch 87/100
# 26/26 - train_loss: 0.8380 - train_accuracy: 84.7595%                 - val_loss: 0.3305 - val_accuracy: 86.3636%
# Epoch 88/100
# 26/26 - train_loss: 0.8296 - train_accuracy: 85.1343%                 - val_loss: 0.3260 - val_accuracy: 86.3636%
# Epoch 89/100
# 26/26 - train_loss: 0.8367 - train_accuracy: 85.0094%                 - val_loss: 0.3251 - val_accuracy: 85.3535%
# Epoch 90/100
# 26/26 - train_loss: 0.8165 - train_accuracy: 84.6971%                 - val_loss: 0.3210 - val_accuracy: 85.8586%
# Epoch 91/100
# 26/26 - train_loss: 0.8152 - train_accuracy: 84.4472%                 - val_loss: 0.3169 - val_accuracy: 86.3636%
# Epoch 92/100
# 26/26 - train_loss: 0.8223 - train_accuracy: 85.0094%                 - val_loss: 0.3140 - val_accuracy: 86.8687%
# Epoch 93/100
# 26/26 - train_loss: 0.8028 - train_accuracy: 84.6971%                 - val_loss: 0.3126 - val_accuracy: 86.8687%
# Epoch 94/100
# 26/26 - train_loss: 0.8045 - train_accuracy: 84.6346%                 - val_loss: 0.3097 - val_accuracy: 86.3636%
# Epoch 95/100
# 26/26 - train_loss: 0.7923 - train_accuracy: 85.6964%                 - val_loss: 0.3078 - val_accuracy: 86.3636%
# Epoch 96/100
# 26/26 - train_loss: 0.7725 - train_accuracy: 85.8214%                 - val_loss: 0.3051 - val_accuracy: 86.8687%
# Epoch 97/100
# 26/26 - train_loss: 0.8123 - train_accuracy: 85.1968%                 - val_loss: 0.3025 - val_accuracy: 86.8687%
# Epoch 98/100
# 26/26 - train_loss: 0.7653 - train_accuracy: 86.1961%                 - val_loss: 0.2983 - val_accuracy: 87.3737%
# Epoch 99/100
# 26/26 - train_loss: 0.7740 - train_accuracy: 86.0087%                 - val_loss: 0.2968 - val_accuracy: 87.3737%
# Epoch 100/100
# 26/26 - train_loss: 0.7612 - train_accuracy: 85.5091%                 - val_loss: 0.2945 - val_accuracy: 87.3737%

# %% [markdown]
# #### <font color="red">**Question 4.3**</font>
# **For any models defined in the previous questions (of all parts), you are free to fine-tune hyperparameters, e.g., `optimizer`, `learning_rate`, `state_sizes`, such that you get a best model, i.e., the one with the highest accuracy on the test set. You will need to report (i) what is your best model,  (ii) its accuracy on the test set, and (iii) the values of its hyperparameters. Note that you must report your best model's accuracy with rounding to 4 decimal places, i.e., 0.xxxx. You will also need to upload your best model (or provide us with the link to download your best model). The assessment will be based on your best model's accuracy, with up to 10 marks available, specifically:**
# * The best accuracy $\ge$ 0.97: 10 marks
# * 0.97 $>$ The best accuracy $\ge$ 0.92: 7 marks
# * 0.92 $>$ The best accuracy $\ge$ 0.85: 4 marks
# * The best accuracy $<$ 0.85: 0 mark
#
# **For this question, you can put below the code to train the best model. In this case, you need to show your code and the evidence of running regarding the best model. Moreover, if you save the best model, you need to provide the link to download the best model, the code to load the best model, and then evaluate on the test set.**
# <div style="text-align: right"><font color="red">[10 marks]</font></div>

# %%
# create the PrefixTuningForClassification model
prefix_tuning_model_3 = PrefixTuningForClassification(model_name = "bert-base-uncased", prefix_length = 20, data_manager = dm).to(device)

# %%
# define the parameters and optimizer and train the model

if prefix_tuning_model_3.prefix_length is not None:
  optimizer = torch.optim.AdamW(list(prefix_tuning_model_3.classifier.parameters()) + [prefix_tuning_model_3.prefix_embeddings], lr=5e-4)
else:
  optimizer = torch.optim.Adam(prefix_tuning_model_3.classifier.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()
trainer = FineTunedBaseTrainer(model= prefix_tuning_model_3, criterion=criterion, optimizer=optimizer, train_loader=train_loader, val_loader=valid_loader)
trainer.fit(num_epochs=150)
# Out:
# Epoch 1/150
# 26/26 - train_loss: 1.6682 - train_accuracy: 22.2361%                 - val_loss: 0.7891 - val_accuracy: 35.8586%
# Epoch 2/150
# 26/26 - train_loss: 1.5859 - train_accuracy: 37.7264%                 - val_loss: 0.7647 - val_accuracy: 46.9697%
# Epoch 3/150
# 26/26 - train_loss: 1.5185 - train_accuracy: 42.5359%                 - val_loss: 0.7255 - val_accuracy: 52.5253%
# Epoch 4/150
# 26/26 - train_loss: 1.4742 - train_accuracy: 49.9063%                 - val_loss: 0.7013 - val_accuracy: 56.0606%
# Epoch 5/150
# 26/26 - train_loss: 1.4369 - train_accuracy: 47.4079%                 - val_loss: 0.6443 - val_accuracy: 57.0707%
# Epoch 6/150
# 26/26 - train_loss: 1.4053 - train_accuracy: 47.7202%                 - val_loss: 0.6254 - val_accuracy: 66.1616%
# Epoch 7/150
# 26/26 - train_loss: 1.3642 - train_accuracy: 53.0918%                 - val_loss: 0.5922 - val_accuracy: 69.1919%
# Epoch 8/150
# 26/26 - train_loss: 1.3131 - train_accuracy: 68.0824%                 - val_loss: 0.5567 - val_accuracy: 70.2020%
# Epoch 9/150
# 26/26 - train_loss: 1.2487 - train_accuracy: 63.5853%                 - val_loss: 0.5281 - val_accuracy: 71.7172%
# Epoch 10/150
# 26/26 - train_loss: 1.2270 - train_accuracy: 65.0219%                 - val_loss: 0.4944 - val_accuracy: 76.7677%
# Epoch 11/150
# 26/26 - train_loss: 1.1527 - train_accuracy: 70.3310%                 - val_loss: 0.4476 - val_accuracy: 76.7677%
# Epoch 12/150
# 26/26 - train_loss: 1.0932 - train_accuracy: 68.7695%                 - val_loss: 0.4178 - val_accuracy: 80.3030%
# Epoch 13/150
# 26/26 - train_loss: 1.1701 - train_accuracy: 72.5796%                 - val_loss: 0.3949 - val_accuracy: 80.3030%
# Epoch 14/150
# 26/26 - train_loss: 1.0463 - train_accuracy: 73.9538%                 - val_loss: 0.3701 - val_accuracy: 79.7980%
# Epoch 15/150
# 26/26 - train_loss: 0.9773 - train_accuracy: 74.3910%                 - val_loss: 0.3426 - val_accuracy: 82.3232%
# Epoch 16/150
# 26/26 - train_loss: 0.9555 - train_accuracy: 77.3267%                 - val_loss: 0.3111 - val_accuracy: 85.8586%
# Epoch 17/150
# 26/26 - train_loss: 0.9435 - train_accuracy: 78.4510%                 - val_loss: 0.2958 - val_accuracy: 86.8687%
# Epoch 18/150
# 26/26 - train_loss: 0.8739 - train_accuracy: 80.1374%                 - val_loss: 0.2765 - val_accuracy: 87.8788%
# Epoch 19/150
# 26/26 - train_loss: 0.8313 - train_accuracy: 79.7002%                 - val_loss: 0.2534 - val_accuracy: 85.8586%
# Epoch 20/150
# 26/26 - train_loss: 0.8093 - train_accuracy: 81.8239%                 - val_loss: 0.2413 - val_accuracy: 87.3737%
# Epoch 21/150
# 26/26 - train_loss: 0.7739 - train_accuracy: 81.3242%                 - val_loss: 0.2251 - val_accuracy: 87.3737%
# Epoch 22/150
# 26/26 - train_loss: 0.7306 - train_accuracy: 83.5103%                 - val_loss: 0.2103 - val_accuracy: 88.8889%
# Epoch 23/150
# 26/26 - train_loss: 0.7039 - train_accuracy: 83.4478%                 - val_loss: 0.1911 - val_accuracy: 89.3939%
# Epoch 24/150
# 26/26 - train_loss: 0.6622 - train_accuracy: 84.4472%                 - val_loss: 0.1781 - val_accuracy: 89.8990%
# Epoch 25/150
# 26/26 - train_loss: 0.6723 - train_accuracy: 85.5091%                 - val_loss: 0.1688 - val_accuracy: 89.8990%
# Epoch 26/150
# 26/26 - train_loss: 0.6413 - train_accuracy: 85.5715%                 - val_loss: 0.1589 - val_accuracy: 90.4040%
# Epoch 27/150
# 26/26 - train_loss: 0.6232 - train_accuracy: 87.2580%                 - val_loss: 0.1496 - val_accuracy: 90.9091%
# Epoch 28/150
# 26/26 - train_loss: 0.5987 - train_accuracy: 87.2580%                 - val_loss: 0.1400 - val_accuracy: 90.9091%
# Epoch 29/150
# 26/26 - train_loss: 0.5543 - train_accuracy: 86.3835%                 - val_loss: 0.1339 - val_accuracy: 90.9091%
# Epoch 30/150
# 26/26 - train_loss: 0.5418 - train_accuracy: 87.7577%                 - val_loss: 0.1289 - val_accuracy: 91.4141%
# Epoch 31/150
# 26/26 - train_loss: 0.5433 - train_accuracy: 88.3198%                 - val_loss: 0.1213 - val_accuracy: 91.9192%
# Epoch 32/150
# 26/26 - train_loss: 0.5437 - train_accuracy: 87.9450%                 - val_loss: 0.1179 - val_accuracy: 91.9192%
# Epoch 33/150
# 26/26 - train_loss: 0.5164 - train_accuracy: 88.6321%                 - val_loss: 0.1167 - val_accuracy: 92.9293%
# Epoch 34/150
# 26/26 - train_loss: 0.5118 - train_accuracy: 89.1318%                 - val_loss: 0.1046 - val_accuracy: 92.4242%
# Epoch 35/150
# 26/26 - train_loss: 0.4788 - train_accuracy: 89.2567%                 - val_loss: 0.1016 - val_accuracy: 91.9192%
# Epoch 36/150
# 26/26 - train_loss: 0.5201 - train_accuracy: 89.6315%                 - val_loss: 0.0995 - val_accuracy: 92.9293%
# Epoch 37/150
# 26/26 - train_loss: 0.4523 - train_accuracy: 90.3186%                 - val_loss: 0.1025 - val_accuracy: 93.4343%
# Epoch 38/150
# 26/26 - train_loss: 0.4336 - train_accuracy: 90.5684%                 - val_loss: 0.0886 - val_accuracy: 92.9293%
# Epoch 39/150
# 26/26 - train_loss: 0.4386 - train_accuracy: 90.6309%                 - val_loss: 0.0860 - val_accuracy: 93.9394%
# Epoch 40/150
# 26/26 - train_loss: 0.4162 - train_accuracy: 90.9432%                 - val_loss: 0.0881 - val_accuracy: 92.9293%
# Epoch 41/150
# 26/26 - train_loss: 0.4066 - train_accuracy: 90.8807%                 - val_loss: 0.0812 - val_accuracy: 93.4343%
# Epoch 42/150
# 26/26 - train_loss: 0.3966 - train_accuracy: 91.3179%                 - val_loss: 0.0771 - val_accuracy: 93.4343%
# Epoch 43/150
# 26/26 - train_loss: 0.3976 - train_accuracy: 91.9425%                 - val_loss: 0.0755 - val_accuracy: 93.9394%
# Epoch 44/150
# 26/26 - train_loss: 0.3963 - train_accuracy: 91.9425%                 - val_loss: 0.0717 - val_accuracy: 93.9394%
# Epoch 45/150
# 26/26 - train_loss: 0.3998 - train_accuracy: 91.3179%                 - val_loss: 0.0738 - val_accuracy: 94.4444%
# Epoch 46/150
# 26/26 - train_loss: 0.3888 - train_accuracy: 92.5671%                 - val_loss: 0.0694 - val_accuracy: 94.4444%
# Epoch 47/150
# 26/26 - train_loss: 0.3607 - train_accuracy: 92.5047%                 - val_loss: 0.0637 - val_accuracy: 93.4343%
# Epoch 48/150
# 26/26 - train_loss: 0.3541 - train_accuracy: 92.1924%                 - val_loss: 0.0659 - val_accuracy: 94.4444%
# Epoch 49/150
# 26/26 - train_loss: 0.3381 - train_accuracy: 92.4422%                 - val_loss: 0.0662 - val_accuracy: 94.4444%
# Epoch 50/150
# 26/26 - train_loss: 0.3275 - train_accuracy: 92.8170%                 - val_loss: 0.0623 - val_accuracy: 94.9495%
# Epoch 51/150
# 26/26 - train_loss: 0.3258 - train_accuracy: 92.6921%                 - val_loss: 0.0608 - val_accuracy: 94.4444%
# Epoch 52/150
# 26/26 - train_loss: 0.3275 - train_accuracy: 92.9419%                 - val_loss: 0.0597 - val_accuracy: 94.4444%
# Epoch 53/150
# 26/26 - train_loss: 0.3446 - train_accuracy: 92.3798%                 - val_loss: 0.0580 - val_accuracy: 94.4444%
# Epoch 54/150
# 26/26 - train_loss: 0.3227 - train_accuracy: 93.2542%                 - val_loss: 0.0561 - val_accuracy: 93.9394%
# Epoch 55/150
# 26/26 - train_loss: 0.3295 - train_accuracy: 92.6296%                 - val_loss: 0.0578 - val_accuracy: 94.9495%
# Epoch 56/150
# 26/26 - train_loss: 0.2999 - train_accuracy: 93.5665%                 - val_loss: 0.0528 - val_accuracy: 93.9394%
# Epoch 57/150
# 26/26 - train_loss: 0.3003 - train_accuracy: 93.0044%                 - val_loss: 0.0533 - val_accuracy: 94.9495%
# Epoch 58/150
# 26/26 - train_loss: 0.2900 - train_accuracy: 93.7539%                 - val_loss: 0.0515 - val_accuracy: 94.4444%
# Epoch 59/150
# 26/26 - train_loss: 0.2878 - train_accuracy: 94.6284%                 - val_loss: 0.0536 - val_accuracy: 94.4444%
# Epoch 60/150
# 26/26 - train_loss: 0.2747 - train_accuracy: 93.8788%                 - val_loss: 0.0558 - val_accuracy: 94.9495%
# Epoch 61/150
# 26/26 - train_loss: 0.2742 - train_accuracy: 93.6290%                 - val_loss: 0.0508 - val_accuracy: 94.4444%
# Epoch 62/150
# 26/26 - train_loss: 0.2644 - train_accuracy: 94.3161%                 - val_loss: 0.0485 - val_accuracy: 94.9495%
# Epoch 63/150
# 26/26 - train_loss: 0.2679 - train_accuracy: 93.9413%                 - val_loss: 0.0491 - val_accuracy: 95.4545%
# Epoch 64/150
# 26/26 - train_loss: 0.2552 - train_accuracy: 94.9407%                 - val_loss: 0.0483 - val_accuracy: 95.4545%
# Epoch 65/150
# 26/26 - train_loss: 0.2585 - train_accuracy: 93.3167%                 - val_loss: 0.0475 - val_accuracy: 94.9495%
# Epoch 66/150
# 26/26 - train_loss: 0.2564 - train_accuracy: 94.0662%                 - val_loss: 0.0454 - val_accuracy: 95.4545%
# Epoch 67/150
# 26/26 - train_loss: 0.2465 - train_accuracy: 95.1280%                 - val_loss: 0.0459 - val_accuracy: 95.9596%
# Epoch 68/150
# 26/26 - train_loss: 0.2370 - train_accuracy: 95.0031%                 - val_loss: 0.0453 - val_accuracy: 95.9596%
# Epoch 69/150
# 26/26 - train_loss: 0.2356 - train_accuracy: 95.3779%                 - val_loss: 0.0436 - val_accuracy: 95.4545%
# Epoch 70/150
# 26/26 - train_loss: 0.2413 - train_accuracy: 95.1280%                 - val_loss: 0.0460 - val_accuracy: 95.9596%
# Epoch 71/150
# 26/26 - train_loss: 0.2302 - train_accuracy: 95.0031%                 - val_loss: 0.0405 - val_accuracy: 95.4545%
# Epoch 72/150
# 26/26 - train_loss: 0.2302 - train_accuracy: 94.8157%                 - val_loss: 0.0420 - val_accuracy: 95.9596%
# Epoch 73/150
# 26/26 - train_loss: 0.2279 - train_accuracy: 95.3779%                 - val_loss: 0.0418 - val_accuracy: 95.9596%
# Epoch 74/150
# 26/26 - train_loss: 0.2305 - train_accuracy: 95.5028%                 - val_loss: 0.0404 - val_accuracy: 95.9596%
# Epoch 75/150
# 26/26 - train_loss: 0.2254 - train_accuracy: 94.8157%                 - val_loss: 0.0390 - val_accuracy: 96.4646%
# Epoch 76/150
# 26/26 - train_loss: 0.2211 - train_accuracy: 95.3154%                 - val_loss: 0.0398 - val_accuracy: 96.4646%
# Epoch 77/150
# 26/26 - train_loss: 0.2149 - train_accuracy: 95.5028%                 - val_loss: 0.0365 - val_accuracy: 96.4646%
# Epoch 78/150
# 26/26 - train_loss: 0.2081 - train_accuracy: 95.4403%                 - val_loss: 0.0375 - val_accuracy: 95.9596%
# Epoch 79/150
# 26/26 - train_loss: 0.2143 - train_accuracy: 95.3154%                 - val_loss: 0.0373 - val_accuracy: 95.9596%
# Epoch 80/150
# 26/26 - train_loss: 0.2143 - train_accuracy: 95.7527%                 - val_loss: 0.0331 - val_accuracy: 96.4646%
# Epoch 81/150
# 26/26 - train_loss: 0.2153 - train_accuracy: 94.8782%                 - val_loss: 0.0294 - val_accuracy: 95.9596%
# Epoch 82/150
# 26/26 - train_loss: 0.1960 - train_accuracy: 95.7527%                 - val_loss: 0.0356 - val_accuracy: 96.4646%
# Epoch 83/150
# 26/26 - train_loss: 0.1913 - train_accuracy: 96.1274%                 - val_loss: 0.0316 - val_accuracy: 95.9596%
# Epoch 84/150
# 26/26 - train_loss: 0.1905 - train_accuracy: 95.3779%                 - val_loss: 0.0325 - val_accuracy: 96.4646%
# Epoch 85/150
# 26/26 - train_loss: 0.1851 - train_accuracy: 95.6902%                 - val_loss: 0.0308 - val_accuracy: 96.4646%
# Epoch 86/150
# 26/26 - train_loss: 0.1860 - train_accuracy: 96.0025%                 - val_loss: 0.0305 - val_accuracy: 95.9596%
# Epoch 87/150
# 26/26 - train_loss: 0.1779 - train_accuracy: 96.3773%                 - val_loss: 0.0308 - val_accuracy: 96.4646%
# Epoch 88/150
# 26/26 - train_loss: 0.2279 - train_accuracy: 95.9400%                 - val_loss: 0.0296 - val_accuracy: 96.9697%
# Epoch 89/150
# 26/26 - train_loss: 0.1959 - train_accuracy: 95.1280%                 - val_loss: 0.0336 - val_accuracy: 97.4747%
# Epoch 90/150
# 26/26 - train_loss: 0.1989 - train_accuracy: 96.1899%                 - val_loss: 0.0324 - val_accuracy: 96.4646%
# Epoch 91/150
# 26/26 - train_loss: 0.1748 - train_accuracy: 96.3773%                 - val_loss: 0.0322 - val_accuracy: 96.9697%
# Epoch 92/150
# 26/26 - train_loss: 0.1809 - train_accuracy: 96.3148%                 - val_loss: 0.0307 - val_accuracy: 96.9697%
# Epoch 93/150
# 26/26 - train_loss: 0.1730 - train_accuracy: 96.3148%                 - val_loss: 0.0318 - val_accuracy: 96.4646%
# Epoch 94/150
# 26/26 - train_loss: 0.1717 - train_accuracy: 97.0019%                 - val_loss: 0.0273 - val_accuracy: 96.4646%
# Epoch 95/150
# 26/26 - train_loss: 0.1721 - train_accuracy: 96.9394%                 - val_loss: 0.0270 - val_accuracy: 96.4646%
# Epoch 96/150
# 26/26 - train_loss: 0.1633 - train_accuracy: 96.0650%                 - val_loss: 0.0269 - val_accuracy: 96.9697%
# Epoch 97/150
# 26/26 - train_loss: 0.1595 - train_accuracy: 96.8770%                 - val_loss: 0.0250 - val_accuracy: 96.4646%
# Epoch 98/150
# 26/26 - train_loss: 0.1537 - train_accuracy: 97.1893%                 - val_loss: 0.0231 - val_accuracy: 96.4646%
# Epoch 99/150
# 26/26 - train_loss: 0.1610 - train_accuracy: 96.5646%                 - val_loss: 0.0238 - val_accuracy: 96.9697%
# Epoch 100/150
# 26/26 - train_loss: 0.1653 - train_accuracy: 96.9394%                 - val_loss: 0.0239 - val_accuracy: 96.9697%
# Epoch 101/150
# 26/26 - train_loss: 0.1505 - train_accuracy: 97.6265%                 - val_loss: 0.0253 - val_accuracy: 96.9697%
# Epoch 102/150
# 26/26 - train_loss: 0.1740 - train_accuracy: 97.5640%                 - val_loss: 0.0210 - val_accuracy: 97.4747%
# Epoch 103/150
# 26/26 - train_loss: 0.1510 - train_accuracy: 96.9394%                 - val_loss: 0.0209 - val_accuracy: 97.4747%
# Epoch 104/150
# 26/26 - train_loss: 0.1500 - train_accuracy: 97.0643%                 - val_loss: 0.0217 - val_accuracy: 96.9697%
# Epoch 105/150
# 26/26 - train_loss: 0.1423 - train_accuracy: 97.1893%                 - val_loss: 0.0217 - val_accuracy: 96.4646%
# Epoch 106/150
# 26/26 - train_loss: 0.1460 - train_accuracy: 97.6265%                 - val_loss: 0.0203 - val_accuracy: 96.9697%
# Epoch 107/150
# 26/26 - train_loss: 0.1475 - train_accuracy: 96.8145%                 - val_loss: 0.0216 - val_accuracy: 96.9697%
# Epoch 108/150
# 26/26 - train_loss: 0.1437 - train_accuracy: 96.8145%                 - val_loss: 0.0208 - val_accuracy: 96.9697%
# Epoch 109/150
# 26/26 - train_loss: 0.1453 - train_accuracy: 97.0019%                 - val_loss: 0.0193 - val_accuracy: 96.4646%
# Epoch 110/150
# 26/26 - train_loss: 0.1421 - train_accuracy: 97.1268%                 - val_loss: 0.0182 - val_accuracy: 97.4747%
# Epoch 111/150
# 26/26 - train_loss: 0.1330 - train_accuracy: 97.4391%                 - val_loss: 0.0175 - val_accuracy: 96.9697%
# Epoch 112/150
# 26/26 - train_loss: 0.1395 - train_accuracy: 97.4391%                 - val_loss: 0.0175 - val_accuracy: 96.9697%
# Epoch 113/150
# 26/26 - train_loss: 0.1363 - train_accuracy: 97.6265%                 - val_loss: 0.0177 - val_accuracy: 96.4646%
# Epoch 114/150
# 26/26 - train_loss: 0.1388 - train_accuracy: 97.2517%                 - val_loss: 0.0162 - val_accuracy: 96.4646%
# Epoch 115/150
# 26/26 - train_loss: 0.1240 - train_accuracy: 98.1886%                 - val_loss: 0.0174 - val_accuracy: 96.4646%
# Epoch 116/150
# 26/26 - train_loss: 0.1251 - train_accuracy: 97.3766%                 - val_loss: 0.0163 - val_accuracy: 96.9697%
# Epoch 117/150
# 26/26 - train_loss: 0.1315 - train_accuracy: 97.5016%                 - val_loss: 0.0153 - val_accuracy: 96.9697%
# Epoch 118/150
# 26/26 - train_loss: 0.1258 - train_accuracy: 97.6889%                 - val_loss: 0.0148 - val_accuracy: 96.9697%
# Epoch 119/150
# 26/26 - train_loss: 0.1276 - train_accuracy: 97.4391%                 - val_loss: 0.0144 - val_accuracy: 96.9697%
# Epoch 120/150
# 26/26 - train_loss: 0.1345 - train_accuracy: 97.5640%                 - val_loss: 0.0142 - val_accuracy: 96.9697%
# Epoch 121/150
# 26/26 - train_loss: 0.1501 - train_accuracy: 98.1262%                 - val_loss: 0.0133 - val_accuracy: 96.4646%
# Epoch 122/150
# 26/26 - train_loss: 0.1313 - train_accuracy: 97.7514%                 - val_loss: 0.0107 - val_accuracy: 97.4747%
# Epoch 123/150
# 26/26 - train_loss: 0.1207 - train_accuracy: 97.8763%                 - val_loss: 0.0146 - val_accuracy: 96.9697%
# Epoch 124/150
# 26/26 - train_loss: 0.1250 - train_accuracy: 97.7514%                 - val_loss: 0.0138 - val_accuracy: 97.4747%
# Epoch 125/150
# 26/26 - train_loss: 0.1213 - train_accuracy: 97.5016%                 - val_loss: 0.0140 - val_accuracy: 97.4747%
# Epoch 126/150
# 26/26 - train_loss: 0.1159 - train_accuracy: 98.0012%                 - val_loss: 0.0135 - val_accuracy: 97.4747%
# Epoch 127/150
# 26/26 - train_loss: 0.1169 - train_accuracy: 97.6265%                 - val_loss: 0.0140 - val_accuracy: 96.4646%
# Epoch 128/150
# 26/26 - train_loss: 0.1109 - train_accuracy: 97.8763%                 - val_loss: 0.0130 - val_accuracy: 97.4747%
# Epoch 129/150
# 26/26 - train_loss: 0.1104 - train_accuracy: 98.1886%                 - val_loss: 0.0120 - val_accuracy: 97.4747%
# Epoch 130/150
# 26/26 - train_loss: 0.1129 - train_accuracy: 97.6265%                 - val_loss: 0.0124 - val_accuracy: 96.9697%
# Epoch 131/150
# 26/26 - train_loss: 0.1150 - train_accuracy: 97.9388%                 - val_loss: 0.0120 - val_accuracy: 97.4747%
# Epoch 132/150
# 26/26 - train_loss: 0.1120 - train_accuracy: 97.8139%                 - val_loss: 0.0118 - val_accuracy: 96.9697%
# Epoch 133/150
# 26/26 - train_loss: 0.1097 - train_accuracy: 98.1262%                 - val_loss: 0.0119 - val_accuracy: 96.4646%
# Epoch 134/150
# 26/26 - train_loss: 0.1057 - train_accuracy: 97.8763%                 - val_loss: 0.0106 - val_accuracy: 96.9697%
# Epoch 135/150
# 26/26 - train_loss: 0.1086 - train_accuracy: 97.8763%                 - val_loss: 0.0110 - val_accuracy: 96.9697%
# Epoch 136/150
# 26/26 - train_loss: 0.1094 - train_accuracy: 97.7514%                 - val_loss: 0.0116 - val_accuracy: 96.4646%
# Epoch 137/150
# 26/26 - train_loss: 0.1042 - train_accuracy: 97.8763%                 - val_loss: 0.0101 - val_accuracy: 97.4747%
# Epoch 138/150
# 26/26 - train_loss: 0.1054 - train_accuracy: 98.0012%                 - val_loss: 0.0102 - val_accuracy: 97.4747%
# Epoch 139/150
# 26/26 - train_loss: 0.1034 - train_accuracy: 98.0637%                 - val_loss: 0.0103 - val_accuracy: 96.9697%
# Epoch 140/150
# 26/26 - train_loss: 0.1021 - train_accuracy: 97.9388%                 - val_loss: 0.0093 - val_accuracy: 97.4747%
# Epoch 141/150
# 26/26 - train_loss: 0.1075 - train_accuracy: 97.6889%                 - val_loss: 0.0102 - val_accuracy: 96.4646%
# Epoch 142/150
# 26/26 - train_loss: 0.0970 - train_accuracy: 98.1886%                 - val_loss: 0.0098 - val_accuracy: 96.9697%
# Epoch 143/150
# 26/26 - train_loss: 0.1085 - train_accuracy: 97.8763%                 - val_loss: 0.0099 - val_accuracy: 96.4646%
# Epoch 144/150
# 26/26 - train_loss: 0.0978 - train_accuracy: 98.2511%                 - val_loss: 0.0085 - val_accuracy: 97.4747%
# Epoch 145/150
# 26/26 - train_loss: 0.0952 - train_accuracy: 98.0012%                 - val_loss: 0.0088 - val_accuracy: 96.9697%
# Epoch 146/150
# 26/26 - train_loss: 0.0990 - train_accuracy: 98.1886%                 - val_loss: 0.0091 - val_accuracy: 96.9697%
# Epoch 147/150
# 26/26 - train_loss: 0.0961 - train_accuracy: 98.0012%                 - val_loss: 0.0084 - val_accuracy: 96.9697%
# Epoch 148/150
# 26/26 - train_loss: 0.0950 - train_accuracy: 98.1886%                 - val_loss: 0.0091 - val_accuracy: 96.4646%
# Epoch 149/150
# 26/26 - train_loss: 0.0928 - train_accuracy: 98.3760%                 - val_loss: 0.0081 - val_accuracy: 96.4646%
# Epoch 150/150
# 26/26 - train_loss: 0.0954 - train_accuracy: 97.8763%                 - val_loss: 0.0082 - val_accuracy: 96.4646%

# %%
# Evaluate the final model on the test set.
print("\nEvaluating on the test set...")

test_loss, test_accuracy = trainer.evaluate(test_loader)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy*100:.4f}%")
# Out:
# Evaluating on the test set...
# Test Loss: 0.0208, Test Accuracy: 98.0100%

# %%
# Save the best model
torch.save(prefix_tuning_model_3.state_dict(), 'best_prefix_model.pth')

# %% [markdown]
# # Give your answer here.
#
# (i) What is your best model?
#
#  **My best model is a Prefix-Tuning classification model based on the bert-base-uncased pre-trained model.**
#
# (ii) The accuracy of your best model on the test set
#
# **Accuracy of the best model on the test set: 98.0100%**
#
# (iii) The values of the hyperparameters of your best model
#
# **The following is the hyperparameter combination that achieved my best performance:**
#
# • model_name: "bert-base-uncased" (same as the baseline)
#
# • prefix_length: 20
#
# • learning_rate (lr): 5e-4
#
# • optimizer: AdamW
#
# • num_epochs: 150

# %% [markdown]
# ---
# <div style="text-align: center"> <font color="green">GOOD LUCK WITH YOUR ASSIGNMENT 2!</font> </div>
# <div style="text-align: center"> <font color="black">END OF ASSIGNMENT</font> </div>
